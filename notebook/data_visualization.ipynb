# %% [markdown]
# # Data Visualization
# * In this notebook we will generate visualization of the data to get initial knowledge of the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline
sns.set()

# %%
data_dir = r'..\data\raw\\'
file_name = data_dir+'data.csv'
df = pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0  index    kn   gn  n_bed   d_int   d_bed  rho_int  rho_bed  \
# 0           0      0  1611  384    156  0.0148  0.0050   877.87  1000.33
# 1           1      1  1611  384    156  0.0148  0.0050   791.04  1000.33
# 2           2      2  1730  311    164  0.0128  0.0049   747.53  1106.81
# 3           3      3  1730  311    164  0.0128  0.0049   791.04  1106.81
# 4           4      4  1396  332    102  0.0123  0.0051   700.26  1104.93
#
#     freq       amp  gamma  zint_i  deg_i   E_pot  zint_f  deg_f  E_pot.1 label
# 0  18.97  0.006588   9.55  0.1074    147  0.0948  1.1074    166   0.1105     A
# 1  18.97  0.006588   9.55  0.1074    147  0.0948  1.1074    166   0.1105     A
# 2  26.60  0.010000  18.60  0.0946    183  0.0897  1.0659    180   0.1010     A
# 3  26.60  0.010000  18.60  0.0946    183  0.0897  1.0659    180   0.1010     A
# 4  28.55  0.010000  25.33  0.1057    144  0.0668  1.0654    156   0.0470     A

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df.describe()
# Out:
#              index           kn          gn       n_bed       d_int  \
# count   913.000000   913.000000  913.000000  913.000000  913.000000
# mean    478.062432  1532.323111  349.559693  147.462212    0.013465
# std     303.942071   296.294872   30.235062   28.775464    0.000870
# min       0.000000  1000.000000  300.000000  100.000000    0.012000
# 25%     228.000000  1295.000000  321.000000  123.000000    0.012700
# 50%     456.000000  1527.000000  350.000000  145.000000    0.013400
# 75%     684.000000  1799.000000  377.000000  172.000000    0.014300
# max    1240.000000  1999.000000  399.000000  199.000000    0.015000
#
#             d_bed     rho_int      rho_bed        freq         amp  \
# count  913.000000  913.000000   913.000000  913.000000  913.000000
# mean     0.005237  798.505936  1094.907306   28.355926    0.008949
# std      0.001027   47.445407    58.041625   11.561912    0.001287
# min      0.004000  700.260000  1000.330000   10.140000    0.006498
# 25%      0.004400  778.460000  1041.510000   18.580000    0.007727
# 50%      0.004900  791.040000  1090.750000   26.600000    0.010000
# 75%      0.005800  827.900000  1143.460000   38.430000    0.010000
# max      0.008000  898.950000  1199.690000   49.960000    0.010000
#
#             gamma      zint_i       deg_i       E_pot      zint_f       deg_f  \
# count  913.000000  913.000000  913.000000  913.000000  913.000000  913.000000
# mean    28.524392    0.103154  184.520263    0.100294    0.470691  194.163198
# std     21.241079    0.046437   75.007338    0.043083    0.323631   86.367906
# min      2.700000    0.020400   13.000000    0.043300    0.021500    2.000000
# 25%     10.300000    0.065800  131.000000    0.069700    0.101700  133.000000
# 50%     21.500000    0.102100  175.000000    0.086700    0.467500  180.000000
# 75%     44.900000    0.134700  226.000000    0.120700    0.756100  242.000000
# max     85.200000    0.235300  415.000000    0.264500    1.141300  462.000000
#
#           E_pot.1
# count  913.000000
# mean     0.094877
# std      0.050265
# min      0.012700
# 25%      0.057800
# 50%      0.086900
# 75%      0.118500
# max      0.252600

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df, x='label')
plt.title('Number of Labels', fontsize=25)
plt.xlabel('Label', fontsize=15)
plt.ylabel('Count Label', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, y='zint_f', x='gamma', hue='label')
plt.title('Number of Labels', fontsize=25)
plt.ylabel('Intruder Final Position', fontsize=15)
plt.xlabel('$\\Gamma$', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df, x='freq', y='amp', hue='label', s=100)
plt.title('Frequency vs Amplitude', fontsize=25)
plt.xlabel('Frequency (Hz)', fontsize=15)
plt.ylabel('Amplitude', fontsize=15)
plt.text(10,0.0096,s="Why?", fontsize=30)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df, x='kn', y='gn', hue='label', s=100)
plt.title('$k_n$ vs $g_n$', fontsize=25)
plt.xlabel('$k_n$', fontsize=15)
plt.ylabel('$g_n$', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df, x='rho_bed', y='rho_int', hue='label', s=100)
plt.title('$\\rho_{int}$ vs $\\rho_{bed}$', fontsize=25)
plt.xlabel('$\\rho_{bed}$', fontsize=15)
plt.ylabel('$\\rho_{int}$', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df.corr(), cmap='Blues')
plt.title('Number of Labels', fontsize=25)
plt.xlabel('Label', fontsize=15)
plt.ylabel('Count Label', fontsize=15)
plt.show()
